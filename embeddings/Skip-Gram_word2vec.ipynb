# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
print(int_words[:10])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import numpy as np
from collections import Counter

word_frequency = Counter(words)
total_word_count = len(words)

def subsample(word_frequency_threshold=1e-5, dropout_threshold=0.5):
    subsampled_int_words = []
    for int_word in int_words:
        freq = word_frequency[int_to_vocab[int_word]] / total_word_count
        subsample_probability = (np.sqrt(word_frequency_threshold / freq))
        
        if subsample_probability > dropout_threshold:
            subsampled_int_words.append(int_word)
    
    return subsampled_int_words
    

train_words = subsample(word_frequency_threshold=1e-5, dropout_threshold=0.4) # The final subsampled word list
print(train_words[:50])
print("We originally had : ", total_word_count)
print("Now we have: ", len(train_words))
# Out:
# [5233, 3080, 3133, 10571, 27349, 15067, 58112, 3580, 10712, 2731, 3672, 2757, 7088, 5233, 44611, 2877, 5233, 2621, 8983, 4147, 6437, 4186, 5233, 1818, 4860, 6753, 7573, 1774, 11064, 7088, 5948, 4861, 20299, 53721, 25636, 7573, 7573, 15200, 1774, 7088, 4860, 5690, 4105, 4331, 8117, 5233, 7088, 2033, 8174, 4148]
# We originally had :  16680599
# Now we have:  4266176

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None), name="inputs")
    labels = tf.placeholder(tf.int32, shape=(None, None), name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w,
                                      biases=softmax_b,
                                      labels=labels,
                                      inputs=embed,
                                      num_sampled=n_sampled,
                                      num_classes=n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 4.8828 0.3646 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 4.8107 0.3339 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 4.7539 0.3584 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 4.8147 0.3355 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 4.7767 0.3320 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.7970 0.3321 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.7703 0.3318 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.7604 0.3336 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.7421 0.3313 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.7607 0.3338 sec/batch
# Nearest to into: gerrymandering, masamune, subsistence, wiens, thereafter, constraints, elegans, loathing,
# Nearest to see: covent, schola, macmanus, goalkeepers, inelegant, thousand, beautiful, dining,
# Nearest to new: barrios, issues, guiana, konstantinos, compel, nights, gasolines, apollodorus,
# Nearest to at: hitchens, following, suitors, mails, lond, crts, berated, workgroups,
# Nearest to so: milarepa, magnetospheric, consultations, connacht, chattanooga, intron, betray, interethnic,
# Nearest to many: swords, bursa, seaborg, rubble, verdun, kubitzki, aemilius, balladeer,
# Nearest to or: influenza, pictures, importing, emmanuel, rajah, brienne, selling, tetra,
# Nearest to which: misrepresentation, obsolescence, tarquinius, envelopment, apace, suggestive, potato, vue,
# Nearest to assembly: trapani, snapping, printing, industrialized, polycrates, segundo, smoothing, exorcist,
# Nearest to woman: encampments, tuna, tempted, usb, wac, rosso, bahamian, vw,
# Nearest to cost: rantissi, location, macroscopic, adic, adverts, gorky, characteristics, syst,
# Nearest to resources: gif, deputies, greases, monash, chadic, townshend, virial, shark,
# Nearest to numerous: rove, lung, neuch, rigours, retires, fulci, northerly, outdone,
# Nearest to pope: ishtar, miming, falsehood, roxen, guilds, overheat, conjunctions, nephew,
# Nearest to brother: sentiments, bestsellers, scifan, jstor, fructose, zodiac, derisively, vaughn,
# Nearest to units: xl, subtracting, saboteur, colored, orcus, polg, impoverishment, occupied,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.6851 0.3364 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.6546 0.3305 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.6306 0.3296 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.6157 0.3293 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.6249 0.3316 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.5983 0.3297 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.5057 0.3295 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.5050 0.3329 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.4273 0.3440 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.3736 0.3325 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, subsistence, thereafter, elegans, constraints, portman,
# Nearest to see: covent, schola, macmanus, goalkeepers, inelegant, dining, thousand, nitriles,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, nights, apollodorus, gasolines,
# Nearest to at: hitchens, following, suitors, mails, crts, lond, cervix, pentecostalism,
# Nearest to so: consultations, milarepa, magnetospheric, connacht, intron, chattanooga, preachers, lynx,
# Nearest to many: swords, bursa, seaborg, rubble, verdun, balladeer, kubitzki, aemilius,
# Nearest to or: influenza, pictures, importing, selling, emmanuel, rajah, forests, brienne,
# Nearest to which: misrepresentation, obsolescence, tarquinius, apace, envelopment, suggestive, vue, turboexpress,
# Nearest to assembly: trapani, printing, snapping, smoothing, industrialized, segundo, mesh, polycrates,
# Nearest to woman: encampments, tuna, usb, tempted, wac, sint, rosso, vw,
# Nearest to cost: rantissi, adic, location, macroscopic, gorky, adverts, fontana, syst,
# Nearest to resources: gif, deputies, greases, townshend, lsp, monash, chadic, virial,
# Nearest to numerous: rove, rigours, neuch, retires, lung, northerly, fulci, invaders,
# Nearest to pope: ishtar, miming, roxen, guilds, falsehood, overheat, conjunctions, espace,
# Nearest to brother: sentiments, bestsellers, jstor, fructose, zodiac, scifan, derisively, vaughn,
# Nearest to units: subtracting, xl, orcus, saboteur, occupied, polg, colored, hate,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.3689 0.3361 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.2726 0.3312 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.2525 0.3282 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.2176 0.3320 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.1443 0.3314 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.1580 0.3292 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.1174 0.3328 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.1462 0.3368 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.1140 0.3343 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.0837 0.3289 sec/batch
# Nearest to into: gerrymandering, wiens, masamune, subsistence, elegans, thereafter, portman, constraints,
# Nearest to see: covent, schola, macmanus, goalkeepers, thousand, inelegant, nitriles, dining,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, nights, apollodorus, gasolines,
# Nearest to at: hitchens, following, suitors, mails, crts, lond, cervix, berated,
# Nearest to so: consultations, milarepa, magnetospheric, mistake, intron, chattanooga, connacht, betray,
# Nearest to many: swords, bursa, verdun, rubble, seaborg, balladeer, kubitzki, bern,
# Nearest to or: influenza, pictures, importing, emmanuel, selling, rajah, brienne, bai,
# Nearest to which: misrepresentation, obsolescence, envelopment, tarquinius, apace, vue, turboexpress, suggestive,
# Nearest to assembly: trapani, printing, snapping, smoothing, mesh, generis, segundo, industrialized,
# Nearest to woman: encampments, tuna, tempted, usb, wac, rosso, sint, bahamian,
# Nearest to cost: rantissi, adic, location, macroscopic, adverts, gorky, fontana, syst,
# Nearest to resources: gif, deputies, greases, townshend, lsp, monash, chadic, virial,
# Nearest to numerous: rove, neuch, rigours, retires, lung, fulci, northerly, outdone,
# Nearest to pope: ishtar, miming, roxen, falsehood, guilds, overheat, espace, chicagoland,
# Nearest to brother: sentiments, bestsellers, jstor, fructose, scifan, derisively, zodiac, militaristic,
# Nearest to units: subtracting, xl, orcus, hate, occupied, saboteur, polg, brent,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.0189 0.3373 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.0405 0.3295 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.0861 0.3350 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.0182 0.3316 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.0355 0.3309 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 3.9840 0.3272 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 3.9486 0.3305 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.0249 0.3281 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 3.8791 0.3284 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 3.9144 0.3535 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, thereafter, subsistence, constraints, warlock,
# Nearest to see: schola, covent, macmanus, goalkeepers, thousand, nitriles, inelegant, spiderweb,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, apollodorus, nights, calder,
# Nearest to at: hitchens, following, suitors, crts, cervix, lond, mails, berated,
# Nearest to so: consultations, milarepa, connacht, magnetospheric, interethnic, mistake, intron, chattanooga,
# Nearest to many: swords, bursa, verdun, seaborg, rubble, kubitzki, bern, balladeer,
# Nearest to or: influenza, pictures, importing, emmanuel, selling, rajah, brienne, bai,
# Nearest to which: misrepresentation, obsolescence, envelopment, tarquinius, vue, apace, turboexpress, suggestive,
# Nearest to assembly: trapani, snapping, segundo, generis, smoothing, printing, mesh, stevenson,
# Nearest to woman: encampments, tempted, tuna, rosso, usb, wac, sint, bahamian,
# Nearest to cost: rantissi, adic, location, macroscopic, adverts, gorky, fontana, syst,
# Nearest to resources: gif, deputies, greases, monash, lsp, townshend, chadic, virial,
# Nearest to numerous: rove, rigours, retires, neuch, lung, fulci, northerly, preproduction,
# Nearest to pope: ishtar, miming, roxen, guilds, falsehood, overheat, rishi, goldoni,
# Nearest to brother: bestsellers, jstor, sentiments, fructose, derisively, vaughn, zodiac, globular,
# Nearest to units: subtracting, occupied, xl, orcus, hate, polg, saboteur, brent,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 3.9517 0.3362 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 3.9323 0.3320 sec/batch
# Epoch 2/10 Iteration: 4300 Avg. Training loss: 3.9325 0.1134 sec/batch
# Epoch 2/10 Iteration: 4400 Avg. Training loss: 3.8247 0.3328 sec/batch
# Epoch 2/10 Iteration: 4500 Avg. Training loss: 3.7936 0.3310 sec/batch
# Epoch 2/10 Iteration: 4600 Avg. Training loss: 3.8186 0.3352 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 3.7533 0.3278 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 3.7395 0.3311 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 3.6957 0.3282 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 3.7699 0.3288 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, constraints, warlock, depictions, portman,
# Nearest to see: schola, covent, macmanus, goalkeepers, thousand, nitriles, inelegant, spiderweb,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, calder, halberd, teammate,
# Nearest to at: hitchens, following, suitors, crts, mails, berated, lond, workgroups,
# Nearest to so: consultations, magnetospheric, milarepa, connacht, chattanooga, mistake, interethnic, intron,
# Nearest to many: swords, bursa, verdun, seaborg, rubble, kubitzki, balladeer, bern,
# Nearest to or: influenza, pictures, importing, emmanuel, rajah, brienne, lio, selling,
# Nearest to which: misrepresentation, obsolescence, envelopment, tarquinius, vue, cnc, apace, turboexpress,
# Nearest to assembly: snapping, trapani, generis, smoothing, alam, segundo, stevenson, mesh,
# Nearest to woman: encampments, tempted, usb, tuna, wac, rosso, sint, talas,
# Nearest to cost: rantissi, adic, location, macroscopic, adverts, gorky, fontana, syst,
# Nearest to resources: gif, deputies, greases, lsp, townshend, monash, chadic, quintet,
# Nearest to numerous: rove, rigours, neuch, retires, northerly, lung, fulci, preproduction,
# Nearest to pope: ishtar, roxen, miming, guilds, falsehood, overheat, rishi, goldoni,
# Nearest to brother: bestsellers, jstor, fructose, scifan, sentiments, globular, vaughn, derisively,
# Nearest to units: occupied, xl, hate, subtracting, orcus, polg, saboteur, amathus,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 3.7222 0.3341 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 3.7566 0.3308 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 3.6210 0.3899 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 3.6367 0.3290 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 3.6688 0.3360 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 3.6785 0.3259 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 3.6416 0.3310 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 3.6594 0.3266 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 3.6295 0.3294 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 3.6416 0.3274 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, depictions, thereafter, warlock, portman,
# Nearest to see: schola, macmanus, covent, thousand, goalkeepers, sovereign, inelegant, provisional,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, calder, halberd, nights,
# Nearest to at: hitchens, following, suitors, mails, lond, workgroups, berated, crts,
# Nearest to so: consultations, magnetospheric, milarepa, connacht, chattanooga, mistake, intron, reportage,
# Nearest to many: swords, bursa, verdun, rubble, seaborg, balladeer, kubitzki, stockport,
# Nearest to or: influenza, pictures, importing, emmanuel, rajah, brienne, lio, selling,
# Nearest to which: misrepresentation, obsolescence, envelopment, tarquinius, vue, cnc, turboexpress, apace,
# Nearest to assembly: snapping, trapani, generis, smoothing, mesh, stevenson, segundo, alam,
# Nearest to woman: encampments, usb, tuna, tempted, wac, sint, rosso, talas,
# Nearest to cost: rantissi, adic, location, macroscopic, gorky, adverts, fontana, thermal,
# Nearest to resources: gif, greases, townshend, deputies, monash, lsp, quintet, chadic,
# Nearest to numerous: rove, rigours, neuch, retires, northerly, lung, fulci, preproduction,
# Nearest to pope: ishtar, roxen, miming, guilds, falsehood, overheat, rishi, conjunctions,
# Nearest to brother: bestsellers, jstor, fructose, globular, sentiments, vaughn, scifan, serengeti,
# Nearest to units: occupied, xl, hate, subtracting, orcus, polg, brent, saboteur,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 3.6914 0.3354 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 3.5917 0.3306 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 3.6132 0.3307 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 3.6524 0.3328 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 3.6663 0.3306 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 3.6485 0.3305 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 3.5728 0.3332 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 3.6067 0.3292 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 3.6267 0.3285 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 3.5758 0.3324 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, depictions, warlock, portman, loathing,
# Nearest to see: schola, thousand, macmanus, covent, goalkeepers, provisional, sovereign, inelegant,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, calder, nights, halberd,
# Nearest to at: following, hitchens, suitors, mails, berated, lond, crts, garagiola,
# Nearest to so: consultations, magnetospheric, milarepa, chattanooga, connacht, mistake, interethnic, intron,
# Nearest to many: swords, bursa, verdun, seaborg, balladeer, kubitzki, rubble, bern,
# Nearest to or: influenza, pictures, importing, emmanuel, rajah, lio, brienne, bai,
# Nearest to which: misrepresentation, obsolescence, envelopment, tarquinius, vue, cnc, turboexpress, windshield,
# Nearest to assembly: snapping, trapani, generis, smoothing, alam, stevenson, segundo, pitch,
# Nearest to woman: encampments, usb, tuna, tempted, wac, sint, rosso, aramaic,
# Nearest to cost: rantissi, macroscopic, location, adic, adverts, gorky, fontana, microwaves,
# Nearest to resources: gif, quintet, monash, townshend, deputies, greases, lsp, chadic,
# Nearest to numerous: rove, northerly, neuch, retires, rigours, lung, fulci, preproduction,
# Nearest to pope: ishtar, roxen, miming, falsehood, guilds, overheat, rishi, autonomous,
# Nearest to brother: bestsellers, jstor, globular, fructose, sentiments, vaughn, serengeti, centime,
# Nearest to units: hate, occupied, xl, subtracting, orcus, polg, brent, saboteur,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 3.5712 0.3348 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 3.6058 0.3296 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 3.4804 0.3327 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 3.5189 0.3264 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 3.5647 0.3334 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 3.6021 0.3310 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 3.6297 0.3337 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 3.6511 0.3285 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 3.4691 0.3316 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 3.5346 0.3267 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, warlock, depictions, portman, loathing,
# Nearest to see: schola, covent, macmanus, thousand, goalkeepers, provisional, sovereign, overthrow,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, calder, halberd, nights,
# Nearest to at: following, hitchens, suitors, berated, garagiola, mails, bushido, lond,
# Nearest to so: consultations, magnetospheric, chattanooga, mistake, milarepa, connacht, interethnic, preachers,
# Nearest to many: bursa, swords, verdun, seaborg, kubitzki, balladeer, rubble, bern,
# Nearest to or: influenza, pictures, importing, rajah, emmanuel, brienne, lio, rafik,
# Nearest to which: misrepresentation, obsolescence, envelopment, tarquinius, vue, cnc, turboexpress, windshield,
# Nearest to assembly: snapping, trapani, generis, segundo, smoothing, stevenson, alam, pitch,
# Nearest to woman: encampments, usb, tuna, tempted, rosso, sint, wac, aramaic,
# Nearest to cost: rantissi, macroscopic, location, adic, adverts, gorky, fontana, microwaves,
# Nearest to resources: gif, quintet, monash, townshend, deputies, lsp, greases, chadic,
# Nearest to numerous: rove, northerly, neuch, rigours, lung, retires, rushen, fulci,
# Nearest to pope: ishtar, roxen, miming, falsehood, overheat, guilds, rishi, conjunctions,
# Nearest to brother: bestsellers, jstor, globular, fructose, vaughn, sentiments, serengeti, centime,
# Nearest to units: hate, xl, subtracting, occupied, orcus, polg, brent, blacksmith,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 3.5349 0.3321 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.4171 0.3290 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 3.5195 0.3348 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 3.5372 0.3296 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 3.5707 0.3315 sec/batch
# Epoch 3/10 Iteration: 8600 Avg. Training loss: 3.5034 0.2242 sec/batch
# Epoch 3/10 Iteration: 8700 Avg. Training loss: 3.4386 0.3325 sec/batch
# Epoch 3/10 Iteration: 8800 Avg. Training loss: 3.4927 0.3349 sec/batch
# Epoch 3/10 Iteration: 8900 Avg. Training loss: 3.4358 0.3284 sec/batch
# Epoch 3/10 Iteration: 9000 Avg. Training loss: 3.3950 0.3509 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, warlock, depictions, phrase, portman,
# Nearest to see: schola, macmanus, goalkeepers, thousand, covent, provisional, sovereign, spiderweb,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, calder, gasolines, halberd,
# Nearest to at: following, hitchens, suitors, berated, garagiola, mails, claes, receptions,
# Nearest to so: consultations, magnetospheric, chattanooga, milarepa, connacht, mistake, interethnic, preachers,
# Nearest to many: bursa, swords, verdun, seaborg, stockport, balladeer, bern, chernenko,
# Nearest to or: influenza, pictures, importing, rajah, emmanuel, brienne, lio, rafik,
# Nearest to which: misrepresentation, obsolescence, envelopment, cnc, tarquinius, vue, trajectory, turboexpress,
# Nearest to assembly: snapping, trapani, generis, segundo, smoothing, alam, stevenson, pitch,
# Nearest to woman: encampments, tuna, tempted, usb, rosso, wac, sint, aramaic,
# Nearest to cost: rantissi, macroscopic, location, adic, gorky, adverts, thermal, microwaves,
# Nearest to resources: gif, quintet, monash, deputies, greases, lsp, townshend, bergomi,
# Nearest to numerous: rove, northerly, rigours, neuch, lung, retires, rushen, fulci,
# Nearest to pope: ishtar, roxen, miming, guilds, falsehood, overheat, rishi, goldoni,
# Nearest to brother: bestsellers, jstor, globular, fructose, vaughn, sentiments, centime, statisticians,
# Nearest to units: hate, occupied, xl, subtracting, orcus, polg, saboteur, amathus,
# Epoch 3/10 Iteration: 9100 Avg. Training loss: 3.4254 0.3412 sec/batch
# Epoch 3/10 Iteration: 9200 Avg. Training loss: 3.3705 0.3309 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 3.4109 0.3265 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.4443 0.3303 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.3820 0.3287 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.2900 0.3306 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.3727 0.3281 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.3570 0.3299 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.3817 0.3286 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.3767 0.3298 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, warlock, depictions, margarine, phrase,
# Nearest to see: schola, macmanus, goalkeepers, provisional, thousand, covent, overthrow, sovereign,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, calder, gasolines, halberd,
# Nearest to at: hitchens, following, suitors, berated, claes, mails, garagiola, receptions,
# Nearest to so: magnetospheric, consultations, mistake, chattanooga, connacht, milarepa, preachers, interethnic,
# Nearest to many: bursa, swords, verdun, seaborg, balladeer, stockport, bern, chernenko,
# Nearest to or: influenza, pictures, rajah, emmanuel, importing, brienne, lio, rafik,
# Nearest to which: obsolescence, misrepresentation, envelopment, cnc, vue, tarquinius, trajectory, turboexpress,
# Nearest to assembly: snapping, trapani, generis, segundo, smoothing, stevenson, alam, orientated,
# Nearest to woman: encampments, tempted, tuna, usb, rosso, wac, sint, forked,
# Nearest to cost: rantissi, macroscopic, location, adic, gorky, adverts, thermal, microwaves,
# Nearest to resources: gif, quintet, monash, deputies, greases, lsp, townshend, bergomi,
# Nearest to numerous: rove, rigours, neuch, retires, northerly, lung, rushen, fulci,
# Nearest to pope: ishtar, roxen, miming, guilds, overheat, falsehood, rishi, persecutors,
# Nearest to brother: bestsellers, jstor, globular, vaughn, sentiments, fructose, centime, hughes,
# Nearest to units: occupied, xl, hate, subtracting, orcus, polg, blacksmith, brent,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.3501 0.3393 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.3654 0.3265 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.4297 0.3285 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.3041 0.3296 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.3924 0.3305 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.3926 0.3300 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.3717 0.3312 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.4017 0.3299 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.3917 0.3327 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.2962 0.3327 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, elegans, warlock, depictions, phrase, margarine,
# Nearest to see: schola, provisional, macmanus, goalkeepers, covent, thousand, overthrow, sovereign,
# Nearest to new: barrios, issues, guiana, compel, konstantinos, gasolines, calder, halberd,
# Nearest to at: suitors, hitchens, following, berated, claes, garagiola, shearer, attendances,
# Nearest to so: magnetospheric, consultations, chattanooga, mistake, connacht, cyprian, interethnic, milarepa,
# Nearest to many: bursa, swords, verdun, balladeer, seaborg, stockport, weighed, chernenko,
# Nearest to or: influenza, pictures, rajah, lio, brienne, emmanuel, importing, engineer,
# Nearest to which: obsolescence, misrepresentation, vue, cnc, envelopment, tarquinius, trajectory, turboexpress,
# Nearest to assembly: snapping, generis, trapani, segundo, smoothing, stevenson, alam, pitch,
# Nearest to woman: encampments, tuna, tempted, usb, wac, rosso, sint, aramaic,
# Nearest to cost: macroscopic, rantissi, location, gorky, adic, adverts, thermal, microwaves,
# Nearest to resources: gif, quintet, monash, deputies, lsp, greases, townshend, bergomi,
# Nearest to numerous: rove, neuch, retires, northerly, rigours, lung, fulci, rushen,
# Nearest to pope: ishtar, roxen, miming, guilds, falsehood, overheat, chicagoland, rishi,
# Nearest to brother: bestsellers, jstor, globular, sentiments, vaughn, hughes, fructose, centime,
# Nearest to units: subtracting, hate, xl, occupied, polg, orcus, saboteur, amathus,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.3623 0.3358 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.3636 0.3286 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.3711 0.3326 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.3640 0.3318 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.3746 0.3303 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.2558 0.3299 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.3227 0.3285 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.3746 0.3330 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.4583 0.3334 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.4197 0.3306 sec/batch
# Nearest to into: gerrymandering, masamune, wiens, warlock, elegans, margarine, depictions, phrase,
# Nearest to see: schola, goalkeepers, macmanus, provisional, thousand, covent, overthrow, sovereign,
# Nearest to new: barrios, issues, guiana, compel, calder, konstantinos, gasolines, halberd,
# Nearest to at: suitors, hitchens, following, claes, berated, shearer, garagiola, attendances,
# Nearest to so: magnetospheric, consultations, chattanooga, mistake, connacht, cyprian, milarepa, interethnic,
# Nearest to many: bursa, swords, verdun, stockport, seaborg, balladeer, weighed, bern,
# Nearest to or: influenza, pictures, brienne, rajah, lio, importing, emmanuel, engineer,
# Nearest to which: obsolescence, misrepresentation, vue, cnc, envelopment, tarquinius, trajectory, turboexpress,
# Nearest to assembly: snapping, generis, trapani, segundo, smoothing, stevenson, pitch, alam,
# Nearest to woman: encampments, tuna, usb, tempted, rosso, wac, sint, aramaic,
# Nearest to cost: macroscopic, rantissi, location, gorky, thermal, adic, adverts, microwaves,
# Nearest to resources: gif, quintet, monash, deputies, lsp, greases, bergomi, owens,
# Nearest to numerous: rove, neuch, rigours, lung, rushen, northerly, fulci, retires,
# Nearest to pope: ishtar, roxen, miming, falsehood, overheat, guilds, rishi, chicagoland,
# Nearest to brother: jstor, globular, bestsellers, sentiments, vaughn, zodiac, hughes, centime,
# Nearest to units: subtracting, xl, hate, occupied, polg, orcus, saboteur, blacksmith,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.4562 0.3323 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.2994 0.3308 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.3390 0.3253 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.2907 0.3296 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.2725 0.3290 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.3379 0.3326 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.3163 0.3321 sec/batch
# Epoch 4/10 Iteration: 12800 Avg. Training loss: 3.3591 0.0070 sec/batch
# Epoch 4/10 Iteration: 12900 Avg. Training loss: 3.3163 0.3285 sec/batch
# Epoch 4/10 Iteration: 13000 Avg. Training loss: 3.2843 0.3319 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, elegans, wiens, margarine, depictions, phrase,
# Nearest to see: schola, macmanus, provisional, goalkeepers, covent, overthrow, thousand, sovereign,
# Nearest to new: barrios, issues, guiana, compel, calder, gasolines, konstantinos, halberd,
# Nearest to at: suitors, following, hitchens, claes, berated, garagiola, shearer, attendances,
# Nearest to so: magnetospheric, consultations, chattanooga, mistake, milarepa, connacht, cyprian, interethnic,
# Nearest to many: bursa, swords, verdun, stockport, seaborg, weighed, balladeer, chernenko,
# Nearest to or: influenza, pictures, rajah, emmanuel, brienne, engineer, lio, importing,
# Nearest to which: misrepresentation, obsolescence, vue, cnc, envelopment, trajectory, tarquinius, turboexpress,
# Nearest to assembly: snapping, generis, trapani, segundo, stevenson, smoothing, alam, laney,
# Nearest to woman: encampments, tuna, usb, tempted, rosso, wac, sint, talas,
# Nearest to cost: macroscopic, rantissi, location, thermal, gorky, adic, adverts, microwaves,
# Nearest to resources: gif, quintet, monash, deputies, bergomi, greases, lsp, octave,
# Nearest to numerous: rove, rigours, neuch, rushen, northerly, fulci, lung, retires,
# Nearest to pope: ishtar, roxen, miming, overheat, chicagoland, falsehood, persecutors, rishi,
# Nearest to brother: globular, jstor, bestsellers, sentiments, vaughn, hughes, centime, zodiac,
# Nearest to units: subtracting, xl, hate, polg, occupied, orcus, saboteur, harriet,
# Epoch 4/10 Iteration: 13100 Avg. Training loss: 3.2916 0.3384 sec/batch
# Epoch 4/10 Iteration: 13200 Avg. Training loss: 3.2647 0.3316 sec/batch
# Epoch 4/10 Iteration: 13300 Avg. Training loss: 3.2970 0.3297 sec/batch
# Epoch 4/10 Iteration: 13400 Avg. Training loss: 3.2174 0.3315 sec/batch
# Epoch 4/10 Iteration: 13500 Avg. Training loss: 3.2139 0.3299 sec/batch
# Epoch 4/10 Iteration: 13600 Avg. Training loss: 3.2927 0.3284 sec/batch
# Epoch 4/10 Iteration: 13700 Avg. Training loss: 3.2870 0.3312 sec/batch
# Epoch 4/10 Iteration: 13800 Avg. Training loss: 3.2569 0.3322 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.1315 0.3289 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.2191 0.3605 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, elegans, wiens, depictions, margarine, nanometres,
# Nearest to see: schola, macmanus, goalkeepers, provisional, covent, thousand, sovereign, overthrow,
# Nearest to new: barrios, issues, guiana, compel, calder, gasolines, konstantinos, halberd,
# Nearest to at: suitors, following, hitchens, claes, berated, crts, attendances, shearer,
# Nearest to so: magnetospheric, consultations, mistake, chattanooga, milarepa, cyprian, connacht, preachers,
# Nearest to many: bursa, swords, verdun, weighed, stockport, seaborg, chernenko, bern,
# Nearest to or: influenza, pictures, emmanuel, rajah, brienne, lio, engineer, rafik,
# Nearest to which: obsolescence, misrepresentation, cnc, vue, envelopment, trajectory, tarquinius, turboexpress,
# Nearest to assembly: snapping, generis, trapani, segundo, stevenson, smoothing, exorcist, laney,
# Nearest to woman: encampments, usb, tuna, tempted, wac, rosso, sint, talas,
# Nearest to cost: location, thermal, rantissi, macroscopic, gorky, microwaves, adic, adverts,
# Nearest to resources: gif, quintet, monash, bergomi, greases, deputies, lsp, mauled,
# Nearest to numerous: rove, rigours, neuch, rushen, northerly, fulci, lung, divisor,
# Nearest to pope: ishtar, roxen, miming, overheat, falsehood, chicagoland, rishi, persecutors,
# Nearest to brother: jstor, globular, sentiments, bestsellers, vaughn, centime, hughes, wallpaper,
# Nearest to units: subtracting, xl, hate, polg, occupied, orcus, saboteur, blacksmith,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.2012 0.3706 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.2442 0.3319 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.2263 0.3280 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.2699 0.3315 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.2323 0.3277 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.2950 0.3310 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.2250 0.3306 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.2126 0.3276 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.2346 0.3302 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.2200 0.3294 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, wiens, elegans, depictions, margarine, nanometres,
# Nearest to see: schola, goalkeepers, provisional, macmanus, sovereign, thousand, covent, overthrow,
# Nearest to new: barrios, issues, guiana, compel, calder, konstantinos, gasolines, tze,
# Nearest to at: following, suitors, hitchens, berated, claes, attendances, crts, shearer,
# Nearest to so: magnetospheric, chattanooga, mistake, consultations, milarepa, cyprian, connacht, retrospective,
# Nearest to many: bursa, swords, weighed, verdun, seaborg, stockport, chernenko, bern,
# Nearest to or: influenza, brienne, emmanuel, engineer, lio, rajah, rafik, pictures,
# Nearest to which: misrepresentation, obsolescence, vue, cnc, trajectory, envelopment, tarquinius, turboexpress,
# Nearest to assembly: snapping, trapani, generis, segundo, smoothing, stevenson, alam, laney,
# Nearest to woman: encampments, usb, tempted, tuna, forked, wac, rosso, sint,
# Nearest to cost: location, rantissi, thermal, gorky, microwaves, macroscopic, adverts, adic,
# Nearest to resources: gif, quintet, monash, bergomi, deputies, lsp, greases, mauled,
# Nearest to numerous: rove, neuch, rigours, rushen, divisor, northerly, lung, frenchy,
# Nearest to pope: ishtar, roxen, miming, falsehood, overheat, chicagoland, persecutors, rishi,
# Nearest to brother: globular, sentiments, jstor, bestsellers, vaughn, centime, compton, zodiac,
# Nearest to units: subtracting, xl, hate, polg, orcus, saboteur, occupied, blacksmith,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.2832 0.3357 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.2357 0.3323 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.2264 0.3308 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.2356 0.3292 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.1886 0.3349 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.2372 0.3299 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.2506 0.3309 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.2000 0.3290 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.1937 0.3279 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.2410 0.3309 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, elegans, wiens, margarine, nanometres, literalism,
# Nearest to see: goalkeepers, schola, macmanus, provisional, thousand, sovereign, covent, overthrow,
# Nearest to new: barrios, issues, guiana, compel, calder, gasolines, konstantinos, tze,
# Nearest to at: suitors, following, hitchens, shearer, berated, attendances, claes, crts,
# Nearest to so: magnetospheric, mistake, chattanooga, consultations, milarepa, cyprian, connacht, none,
# Nearest to many: bursa, swords, verdun, stockport, weighed, seaborg, chernenko, balladeer,
# Nearest to or: influenza, rajah, emmanuel, lio, rafik, brienne, pictures, engineer,
# Nearest to which: misrepresentation, obsolescence, vue, cnc, envelopment, trajectory, turboexpress, tarquinius,
# Nearest to assembly: snapping, trapani, generis, segundo, smoothing, stevenson, alam, laney,
# Nearest to woman: encampments, usb, tempted, tuna, forked, wac, rosso, talas,
# Nearest to cost: location, thermal, microwaves, rantissi, gorky, adverts, macroscopic, adic,
# Nearest to resources: gif, quintet, monash, deputies, bergomi, lsp, octave, mauled,
# Nearest to numerous: rove, neuch, rigours, rushen, northerly, divisor, lung, frenchy,
# Nearest to pope: ishtar, roxen, miming, overheat, falsehood, chicagoland, persecutors, guilds,
# Nearest to brother: jstor, globular, sentiments, bestsellers, vaughn, centime, hughes, wallpaper,
# Nearest to units: subtracting, xl, hate, polg, orcus, saboteur, harriet, blacksmith,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.2508 0.3393 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.3563 0.3301 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.2966 0.3303 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.2771 0.3322 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.1675 0.3280 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.2651 0.3271 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.0663 0.3297 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.2509 0.3317 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.2054 0.3307 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.2185 0.3321 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, margarine, elegans, nanometres, wiens, phrase,
# Nearest to see: goalkeepers, schola, macmanus, provisional, sovereign, overthrow, thousand, covent,
# Nearest to new: barrios, issues, guiana, compel, calder, gasolines, konstantinos, tze,
# Nearest to at: following, suitors, hitchens, berated, attendances, shearer, claes, garagiola,
# Nearest to so: chattanooga, mistake, magnetospheric, consultations, cyprian, milarepa, connacht, retrospective,
# Nearest to many: bursa, swords, verdun, weighed, seaborg, stockport, chernenko, balladeer,
# Nearest to or: influenza, rajah, lio, emmanuel, rafik, brienne, pictures, engineer,
# Nearest to which: misrepresentation, obsolescence, vue, cnc, envelopment, trajectory, turboexpress, tarquinius,
# Nearest to assembly: trapani, generis, snapping, segundo, smoothing, stevenson, laney, exorcist,
# Nearest to woman: encampments, usb, tuna, tempted, rosso, wac, forked, sint,
# Nearest to cost: location, microwaves, thermal, gorky, rantissi, adverts, macroscopic, adic,
# Nearest to resources: gif, quintet, monash, deputies, bergomi, yelled, lsp, mauled,
# Nearest to numerous: rove, neuch, rigours, divisor, northerly, rushen, frenchy, biography,
# Nearest to pope: ishtar, roxen, miming, chicagoland, persecutors, falsehood, overheat, rishi,
# Nearest to brother: sentiments, globular, jstor, bestsellers, vaughn, compton, centime, hughes,
# Nearest to units: subtracting, polg, hate, xl, orcus, rains, harriet, saboteur,
# Epoch 5/10 Iteration: 17100 Avg. Training loss: 3.3048 0.1184 sec/batch
# Epoch 5/10 Iteration: 17200 Avg. Training loss: 3.1649 0.3301 sec/batch
# Epoch 5/10 Iteration: 17300 Avg. Training loss: 3.1790 0.3312 sec/batch
# Epoch 5/10 Iteration: 17400 Avg. Training loss: 3.2146 0.3344 sec/batch
# Epoch 5/10 Iteration: 17500 Avg. Training loss: 3.1349 0.3292 sec/batch
# Epoch 5/10 Iteration: 17600 Avg. Training loss: 3.1506 0.3313 sec/batch
# Epoch 5/10 Iteration: 17700 Avg. Training loss: 3.0866 0.3290 sec/batch
# Epoch 5/10 Iteration: 17800 Avg. Training loss: 3.1499 0.3292 sec/batch
# Epoch 5/10 Iteration: 17900 Avg. Training loss: 3.1756 0.3285 sec/batch
# Epoch 5/10 Iteration: 18000 Avg. Training loss: 3.1971 0.3303 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, margarine, nanometres, wiens, literalism, elegans,
# Nearest to see: goalkeepers, schola, provisional, macmanus, sovereign, overthrow, thousand, covent,
# Nearest to new: barrios, issues, guiana, compel, calder, konstantinos, gasolines, tze,
# Nearest to at: suitors, following, hitchens, berated, shearer, attendances, claes, garagiola,
# Nearest to so: mistake, chattanooga, magnetospheric, consultations, milarepa, cyprian, connacht, none,
# Nearest to many: bursa, swords, weighed, verdun, seaborg, stockport, chernenko, balladeer,
# Nearest to or: influenza, rajah, lio, rafik, pictures, brienne, emmanuel, engineer,
# Nearest to which: obsolescence, cnc, misrepresentation, vue, trajectory, envelopment, turboexpress, tarquinius,
# Nearest to assembly: trapani, snapping, generis, stevenson, segundo, smoothing, laney, exorcist,
# Nearest to woman: encampments, usb, tempted, rosso, forked, wac, tuna, talas,
# Nearest to cost: location, thermal, microwaves, gorky, rantissi, adverts, macroscopic, adic,
# Nearest to resources: gif, quintet, monash, deputies, yelled, bergomi, atm, lsp,
# Nearest to numerous: rove, rigours, neuch, divisor, rushen, northerly, frenchy, biography,
# Nearest to pope: ishtar, roxen, miming, chicagoland, persecutors, falsehood, overheat, rishi,
# Nearest to brother: globular, sentiments, jstor, bestsellers, wallpaper, vaughn, compton, centime,
# Nearest to units: subtracting, hate, polg, xl, orcus, harriet, rains, saboteur,
# Epoch 5/10 Iteration: 18100 Avg. Training loss: 3.0258 0.3358 sec/batch
# Epoch 5/10 Iteration: 18200 Avg. Training loss: 3.0846 0.3328 sec/batch
# Epoch 5/10 Iteration: 18300 Avg. Training loss: 3.1047 0.3298 sec/batch
# Epoch 5/10 Iteration: 18400 Avg. Training loss: 3.0900 0.3269 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 3.1497 0.3297 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.1692 0.3294 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.1212 0.3280 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.1840 0.3308 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.1941 0.3292 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.0728 0.3302 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, nanometres, margarine, elegans, depictions, grace,
# Nearest to see: goalkeepers, provisional, schola, overthrow, macmanus, sovereign, fg, covent,
# Nearest to new: barrios, issues, guiana, compel, calder, konstantinos, gasolines, tze,
# Nearest to at: suitors, following, hitchens, berated, shearer, claes, attendances, crts,
# Nearest to so: mistake, magnetospheric, chattanooga, milarepa, consultations, cyprian, connacht, assembles,
# Nearest to many: bursa, swords, weighed, verdun, chernenko, stockport, seaborg, balladeer,
# Nearest to or: influenza, rajah, lio, rafik, brienne, engineer, emmanuel, pictures,
# Nearest to which: vue, obsolescence, cnc, misrepresentation, trajectory, envelopment, turboexpress, tarquinius,
# Nearest to assembly: snapping, trapani, generis, stevenson, segundo, smoothing, laney, exorcist,
# Nearest to woman: encampments, usb, tempted, forked, rosso, wac, tuna, talas,
# Nearest to cost: location, gorky, microwaves, thermal, rantissi, adverts, macroscopic, adic,
# Nearest to resources: gif, quintet, monash, bergomi, atm, deputies, yelled, liegnitz,
# Nearest to numerous: rove, rigours, neuch, divisor, northerly, rushen, frenchy, biography,
# Nearest to pope: ishtar, roxen, persecutors, miming, overheat, chicagoland, falsehood, rishi,
# Nearest to brother: sentiments, globular, jstor, bestsellers, vaughn, compton, wallpaper, centime,
# Nearest to units: subtracting, hate, polg, xl, orcus, harriet, saboteur, rains,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.1409 0.3394 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.1549 0.3307 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.1712 0.3292 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.2273 0.3281 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.1150 0.3311 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.1623 0.3296 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.1793 0.3306 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.1402 0.3302 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.0791 0.3296 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.1957 0.3307 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, nanometres, margarine, elegans, grace, wiens,
# Nearest to see: overthrow, schola, goalkeepers, provisional, macmanus, sovereign, fg, covent,
# Nearest to new: barrios, issues, guiana, calder, compel, konstantinos, arrivals, gasolines,
# Nearest to at: suitors, following, hitchens, berated, shearer, claes, garagiola, rensselaer,
# Nearest to so: mistake, chattanooga, magnetospheric, consultations, milarepa, cyprian, connacht, assembles,
# Nearest to many: bursa, swords, verdun, weighed, chernenko, seaborg, stockport, balladeer,
# Nearest to or: influenza, rajah, emmanuel, brienne, rafik, lio, engineer, conscripts,
# Nearest to which: vue, obsolescence, cnc, misrepresentation, turboexpress, trajectory, envelopment, tarquinius,
# Nearest to assembly: trapani, snapping, generis, stevenson, smoothing, segundo, exorcist, laney,
# Nearest to woman: encampments, usb, tempted, forked, tuna, wac, rosso, talas,
# Nearest to cost: location, gorky, microwaves, thermal, rantissi, adverts, macroscopic, roared,
# Nearest to resources: gif, quintet, monash, bergomi, deputies, capetian, yelled, atm,
# Nearest to numerous: rove, rigours, neuch, divisor, northerly, rushen, lung, frenchy,
# Nearest to pope: ishtar, roxen, miming, persecutors, overheat, chicagoland, falsehood, rishi,
# Nearest to brother: sentiments, globular, bestsellers, jstor, wallpaper, compton, vaughn, hughes,
# Nearest to units: subtracting, hate, polg, xl, orcus, harriet, rains, saboteur,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.1112 0.3346 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.0892 0.3289 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.2258 0.3353 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.2171 0.3307 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.2696 0.3303 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.2295 0.3281 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.1101 0.3297 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.1277 0.3259 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.1378 0.3298 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.0457 0.3309 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, nanometres, margarine, grace, kushan, elegans,
# Nearest to see: schola, overthrow, goalkeepers, provisional, macmanus, sovereign, fg, covent,
# Nearest to new: barrios, issues, guiana, compel, calder, konstantinos, gasolines, arrivals,
# Nearest to at: following, suitors, hitchens, berated, claes, shearer, rensselaer, garagiola,
# Nearest to so: chattanooga, mistake, magnetospheric, connacht, cyprian, milarepa, consultations, assembles,
# Nearest to many: bursa, weighed, verdun, swords, chernenko, seaborg, stockport, lifting,
# Nearest to or: influenza, brienne, rajah, lio, emmanuel, pictures, rafik, engineer,
# Nearest to which: vue, obsolescence, cnc, misrepresentation, turboexpress, trajectory, envelopment, windshield,
# Nearest to assembly: trapani, snapping, stevenson, smoothing, generis, segundo, exorcist, laney,
# Nearest to woman: encampments, usb, tempted, forked, talas, rosso, tuna, wac,
# Nearest to cost: gorky, location, microwaves, rantissi, thermal, adverts, roared, macroscopic,
# Nearest to resources: gif, quintet, monash, yelled, atm, bergomi, deputies, greases,
# Nearest to numerous: rove, rigours, neuch, divisor, rushen, northerly, murat, frenchy,
# Nearest to pope: ishtar, roxen, persecutors, miming, overheat, chicagoland, correction, rishi,
# Nearest to brother: sentiments, globular, jstor, bestsellers, vaughn, wallpaper, hughes, centime,
# Nearest to units: subtracting, polg, hate, orcus, xl, rains, brent, harriet,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.1741 0.3388 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.1117 0.3294 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.1867 0.3326 sec/batch
# Epoch 6/10 Iteration: 21400 Avg. Training loss: 3.1384 0.2320 sec/batch
# Epoch 6/10 Iteration: 21500 Avg. Training loss: 3.1243 0.3316 sec/batch
# Epoch 6/10 Iteration: 21600 Avg. Training loss: 3.1375 0.3349 sec/batch
# Epoch 6/10 Iteration: 21700 Avg. Training loss: 3.1788 0.3309 sec/batch
# Epoch 6/10 Iteration: 21800 Avg. Training loss: 3.0867 0.3329 sec/batch
# Epoch 6/10 Iteration: 21900 Avg. Training loss: 3.0832 0.3291 sec/batch
# Epoch 6/10 Iteration: 22000 Avg. Training loss: 3.0398 0.3308 sec/batch
# Nearest to into: gerrymandering, masamune, warlock, nanometres, margarine, kushan, grace, sinful,
# Nearest to see: schola, overthrow, goalkeepers, sovereign, macmanus, provisional, fg, covent,
# Nearest to new: barrios, issues, guiana, compel, calder, konstantinos, arrivals, gasolines,
# Nearest to at: following, hitchens, suitors, berated, attendances, pico, shearer, claes,
# Nearest to so: mistake, chattanooga, magnetospheric, milarepa, connacht, cyprian, consultations, hour,
# Nearest to many: bursa, weighed, swords, verdun, seaborg, chernenko, stockport, framers,
# Nearest to or: influenza, lio, brienne, rajah, pictures, emmanuel, engineer, rafik,
# Nearest to which: vue, obsolescence, cnc, misrepresentation, turboexpress, envelopment, trajectory, reflectors,
# Nearest to assembly: trapani, snapping, smoothing, generis, stevenson, segundo, exorcist, laney,
# Nearest to woman: encampments, tempted, forked, usb, talas, tuna, wac, rosso,
# Nearest to cost: location, thermal, microwaves, gorky, rantissi, adverts, roared, ergonomic,
# Nearest to resources: gif, monash, quintet, yelled, bergomi, greases, departs, deputies,
# ...
# Nearest to pope: ishtar, persecutors, roxen, miming, bearer, brillig, capture, pounded,
# Nearest to brother: sentiments, compton, tasmania, automation, jstor, studd, starfleet, epona,
# Nearest to units: subtracting, polg, hate, harriet, orcus, rains, xl, amathus,
# Epoch 9/10 Iteration: 35100 Avg. Training loss: 3.0157 0.3343 sec/batch
# Epoch 9/10 Iteration: 35200 Avg. Training loss: 2.8404 0.3287 sec/batch
# Epoch 9/10 Iteration: 35300 Avg. Training loss: 2.9298 0.3282 sec/batch
# Epoch 9/10 Iteration: 35400 Avg. Training loss: 2.9534 0.3323 sec/batch
# Epoch 9/10 Iteration: 35500 Avg. Training loss: 2.9789 0.3270 sec/batch
# Epoch 9/10 Iteration: 35600 Avg. Training loss: 3.0123 0.3312 sec/batch
# Epoch 9/10 Iteration: 35700 Avg. Training loss: 2.9586 0.3618 sec/batch
# Epoch 9/10 Iteration: 35800 Avg. Training loss: 2.9659 0.3276 sec/batch
# Epoch 9/10 Iteration: 35900 Avg. Training loss: 3.0696 0.3311 sec/batch
# Epoch 9/10 Iteration: 36000 Avg. Training loss: 3.0007 0.3295 sec/batch
# Nearest to into: gerrymandering, kushan, masamune, warlock, margarine, grace, sinful, saskatchewan,
# Nearest to see: goalkeepers, overthrow, schola, fg, macmanus, monarch, provisional, blindness,
# Nearest to new: barrios, issues, arrivals, guiana, konstantinos, dislodge, calder, swell,
# Nearest to at: following, claes, hobbyists, crts, pico, garagiola, lond, hitchens,
# Nearest to so: hour, chattanooga, cyprian, mistake, connacht, assembles, kimball, milarepa,
# Nearest to many: weighed, bursa, seaborg, swords, verdun, balladeer, weigh, chernenko,
# Nearest to or: influenza, rafik, rajah, brienne, emmanuel, conscripts, arborway, tabbed,
# Nearest to which: vue, cnc, turboexpress, misrepresentation, trajectory, fft, reflectors, tsunami,
# Nearest to assembly: smoothing, trapani, exorcist, farinelli, snapping, stevenson, phoneticians, laney,
# Nearest to woman: encampments, forked, sint, usb, talas, tempted, wac, tuna,
# Nearest to cost: location, gorky, microwaves, roared, rally, ergonomic, thermal, aldo,
# Nearest to resources: gif, monash, departs, bergomi, liegnitz, liza, greases, atm,
# Nearest to numerous: rove, neuch, rushen, divisor, murat, rigours, frenchy, biography,
# Nearest to pope: ishtar, persecutors, roxen, miming, brillig, bearer, pounded, chicagoland,
# Nearest to brother: sentiments, compton, tasmania, epona, automation, jstor, studd, centime,
# Nearest to units: subtracting, polg, hate, harriet, xl, orcus, rains, amathus,
# Epoch 9/10 Iteration: 36100 Avg. Training loss: 2.9924 0.3335 sec/batch
# Epoch 9/10 Iteration: 36200 Avg. Training loss: 2.9479 0.3296 sec/batch
# Epoch 9/10 Iteration: 36300 Avg. Training loss: 2.9797 0.3367 sec/batch
# Epoch 9/10 Iteration: 36400 Avg. Training loss: 3.0589 0.3275 sec/batch
# Epoch 9/10 Iteration: 36500 Avg. Training loss: 3.0690 0.3317 sec/batch
# Epoch 9/10 Iteration: 36600 Avg. Training loss: 2.9290 0.3312 sec/batch
# Epoch 9/10 Iteration: 36700 Avg. Training loss: 2.9920 0.3304 sec/batch
# Epoch 9/10 Iteration: 36800 Avg. Training loss: 3.0169 0.3298 sec/batch
# Epoch 9/10 Iteration: 36900 Avg. Training loss: 3.0163 0.3308 sec/batch
# Epoch 9/10 Iteration: 37000 Avg. Training loss: 3.0462 0.3294 sec/batch
# Nearest to into: gerrymandering, kushan, masamune, warlock, margarine, grace, saskatchewan, sinful,
# Nearest to see: goalkeepers, overthrow, fg, schola, monarch, macmanus, blindness, provisional,
# Nearest to new: barrios, issues, arrivals, guiana, konstantinos, dislodge, calder, swell,
# Nearest to at: following, claes, hobbyists, crts, garagiola, pico, attendances, lond,
# Nearest to so: chattanooga, hour, cyprian, mistake, connacht, assembles, kimball, milarepa,
# Nearest to many: weighed, bursa, seaborg, swords, verdun, balladeer, weigh, photographer,
# Nearest to or: influenza, rafik, rajah, conscripts, emmanuel, brienne, pictures, arborway,
# Nearest to which: vue, cnc, turboexpress, misrepresentation, trajectory, reflectors, fft, tsunami,
# Nearest to assembly: smoothing, trapani, snapping, farinelli, exorcist, stevenson, phoneticians, laney,
# Nearest to woman: encampments, forked, talas, usb, sint, tempted, wac, tuna,
# Nearest to cost: gorky, location, roared, microwaves, rally, ergonomic, turtledove, aldo,
# Nearest to resources: gif, monash, bergomi, departs, liegnitz, greases, writs, liza,
# Nearest to numerous: rove, neuch, rushen, divisor, murat, frenchy, biography, rigours,
# Nearest to pope: ishtar, persecutors, miming, roxen, brillig, correction, pounded, enmity,
# Nearest to brother: sentiments, tasmania, compton, epona, starfleet, automation, studd, centime,
# Nearest to units: subtracting, hate, polg, rains, xl, orcus, harriet, lorraine,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 2.9835 0.3365 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 2.8946 0.3304 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 2.9478 0.3292 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.0193 0.3315 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.1359 0.3505 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.1240 0.3319 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.0455 0.3297 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 2.9338 0.3328 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 2.9519 0.3258 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 2.9512 0.3304 sec/batch
# Nearest to into: gerrymandering, masamune, kushan, warlock, margarine, grace, sinful, saskatchewan,
# Nearest to see: goalkeepers, overthrow, fg, schola, monarch, macmanus, blindness, astrologically,
# Nearest to new: barrios, issues, arrivals, guiana, konstantinos, dislodge, calder, swell,
# Nearest to at: following, claes, hobbyists, crts, garagiola, attendances, pico, lond,
# Nearest to so: chattanooga, cyprian, mistake, hour, connacht, assembles, kimball, noodle,
# Nearest to many: weighed, bursa, seaborg, photographer, swords, verdun, weigh, balladeer,
# Nearest to or: influenza, rafik, rajah, pictures, conscripts, brienne, tabbed, emmanuel,
# Nearest to which: vue, cnc, turboexpress, misrepresentation, trajectory, fft, windshield, reflectors,
# Nearest to assembly: smoothing, snapping, farinelli, trapani, exorcist, stevenson, phoneticians, laney,
# Nearest to woman: encampments, forked, usb, sint, talas, tuna, wac, tempted,
# Nearest to cost: location, gorky, roared, microwaves, rally, ergonomic, turtledove, aldo,
# Nearest to resources: gif, monash, departs, bergomi, liza, liegnitz, greases, writs,
# Nearest to numerous: rove, neuch, rushen, divisor, rigours, frenchy, biography, murat,
# Nearest to pope: ishtar, persecutors, miming, roxen, brillig, pounded, bearer, chicagoland,
# Nearest to brother: sentiments, tasmania, epona, starfleet, compton, studd, automation, centime,
# Nearest to units: subtracting, hate, polg, rains, lorraine, xl, harriet, orcus,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 2.9579 0.3369 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 2.9788 0.3431 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.0145 0.3297 sec/batch
# Epoch 10/10 Iteration: 38400 Avg. Training loss: 3.0378 0.0201 sec/batch
# Epoch 10/10 Iteration: 38500 Avg. Training loss: 3.0045 0.3305 sec/batch
# Epoch 10/10 Iteration: 38600 Avg. Training loss: 3.0009 0.3318 sec/batch
# Epoch 10/10 Iteration: 38700 Avg. Training loss: 3.0264 0.3343 sec/batch
# Epoch 10/10 Iteration: 38800 Avg. Training loss: 2.9596 0.3799 sec/batch
# Epoch 10/10 Iteration: 38900 Avg. Training loss: 2.9774 0.3761 sec/batch
# Epoch 10/10 Iteration: 39000 Avg. Training loss: 2.9246 0.3861 sec/batch
# Nearest to into: gerrymandering, masamune, kushan, warlock, margarine, saskatchewan, sinful, sect,
# Nearest to see: goalkeepers, overthrow, schola, fg, monarch, macmanus, blindness, astrologically,
# Nearest to new: barrios, issues, arrivals, guiana, konstantinos, dislodge, swell, calder,
# Nearest to at: following, hobbyists, claes, attendances, garagiola, crts, pico, hitchens,
# Nearest to so: chattanooga, mistake, cyprian, connacht, hour, assembles, noodle, milarepa,
# Nearest to many: weighed, bursa, seaborg, photographer, weigh, swords, verdun, balladeer,
# Nearest to or: influenza, rafik, rajah, conscripts, tabbed, pictures, arborway, brienne,
# Nearest to which: vue, cnc, misrepresentation, turboexpress, trajectory, windshield, fft, reflectors,
# Nearest to assembly: smoothing, snapping, farinelli, exorcist, trapani, stevenson, contrabassoon, folksong,
# Nearest to woman: encampments, forked, sint, usb, talas, tuna, wac, tempted,
# Nearest to cost: gorky, location, roared, microwaves, rally, ergonomic, turtledove, aldo,
# Nearest to resources: gif, monash, departs, liegnitz, bergomi, greases, yelled, liza,
# Nearest to numerous: rove, neuch, rushen, divisor, frenchy, rigours, biography, murat,
# Nearest to pope: ishtar, persecutors, miming, roxen, brillig, bearer, pounded, symbolism,
# Nearest to brother: sentiments, tasmania, studd, automation, epona, starfleet, mounted, compton,
# Nearest to units: subtracting, hate, polg, rains, xl, harriet, amathus, lorraine,
# Epoch 10/10 Iteration: 39100 Avg. Training loss: 2.9063 0.3352 sec/batch
# Epoch 10/10 Iteration: 39200 Avg. Training loss: 2.9617 0.3266 sec/batch
# Epoch 10/10 Iteration: 39300 Avg. Training loss: 3.0120 0.3318 sec/batch
# Epoch 10/10 Iteration: 39400 Avg. Training loss: 2.9584 0.3313 sec/batch
# Epoch 10/10 Iteration: 39500 Avg. Training loss: 2.8482 0.3322 sec/batch
# Epoch 10/10 Iteration: 39600 Avg. Training loss: 2.9265 0.3280 sec/batch
# Epoch 10/10 Iteration: 39700 Avg. Training loss: 2.8878 0.3292 sec/batch
# Epoch 10/10 Iteration: 39800 Avg. Training loss: 2.9746 0.3293 sec/batch
# Epoch 10/10 Iteration: 39900 Avg. Training loss: 2.9508 0.3315 sec/batch
# Epoch 10/10 Iteration: 40000 Avg. Training loss: 2.9744 0.3298 sec/batch
# Nearest to into: gerrymandering, masamune, kushan, warlock, margarine, literalism, grace, saskatchewan,
# Nearest to see: goalkeepers, overthrow, schola, fg, monarch, macmanus, blindness, sovereign,
# Nearest to new: barrios, issues, arrivals, guiana, konstantinos, dislodge, calder, swell,
# Nearest to at: following, claes, hobbyists, garagiola, crts, attendances, hitchens, grandmaster,
# Nearest to so: cyprian, mistake, chattanooga, hour, connacht, assembles, noodle, none,
# Nearest to many: weighed, bursa, seaborg, verdun, photographer, swords, weigh, balladeer,
# Nearest to or: influenza, rafik, rajah, conscripts, tabbed, arborway, pictures, brienne,
# Nearest to which: vue, cnc, turboexpress, misrepresentation, trajectory, windshield, fft, reflectors,
# Nearest to assembly: snapping, smoothing, exorcist, trapani, farinelli, stevenson, contrabassoon, phoneticians,
# Nearest to woman: encampments, forked, talas, usb, sint, tuna, wac, rosso,
# Nearest to cost: gorky, location, roared, microwaves, rally, turtledove, ergonomic, aldo,
# Nearest to resources: gif, monash, departs, liegnitz, bergomi, greases, yelled, liza,
# Nearest to numerous: rove, neuch, rushen, divisor, rigours, murat, biography, frenchy,
# Nearest to pope: ishtar, persecutors, miming, roxen, brillig, symbolism, bearer, pounded,
# Nearest to brother: sentiments, tasmania, studd, epona, automation, compton, starfleet, mounted,
# Nearest to units: subtracting, hate, polg, rains, xl, harriet, lorraine, amathus,
# Epoch 10/10 Iteration: 40100 Avg. Training loss: 2.9747 0.3359 sec/batch
# Epoch 10/10 Iteration: 40200 Avg. Training loss: 3.0354 0.3307 sec/batch
# Epoch 10/10 Iteration: 40300 Avg. Training loss: 2.9398 0.3296 sec/batch
# Epoch 10/10 Iteration: 40400 Avg. Training loss: 2.9433 0.3293 sec/batch
# Epoch 10/10 Iteration: 40500 Avg. Training loss: 2.9808 0.3311 sec/batch
# Epoch 10/10 Iteration: 40600 Avg. Training loss: 2.9654 0.3323 sec/batch
# Epoch 10/10 Iteration: 40700 Avg. Training loss: 3.0490 0.3293 sec/batch
# Epoch 10/10 Iteration: 40800 Avg. Training loss: 2.9944 0.3316 sec/batch
# Epoch 10/10 Iteration: 40900 Avg. Training loss: 2.9861 0.3308 sec/batch
# Epoch 10/10 Iteration: 41000 Avg. Training loss: 2.9940 0.3289 sec/batch
# Nearest to into: gerrymandering, kushan, masamune, warlock, margarine, saskatchewan, literalism, sect,
# Nearest to see: goalkeepers, overthrow, fg, schola, monarch, blindness, macmanus, sovereign,
# Nearest to new: issues, barrios, arrivals, guiana, reissue, dislodge, konstantinos, calder,
# Nearest to at: following, claes, hobbyists, garagiola, crts, attendances, lond, pyne,
# Nearest to so: cyprian, mistake, chattanooga, hour, connacht, assembles, none, noodle,
# Nearest to many: weighed, bursa, seaborg, swords, photographer, verdun, weigh, balladeer,
# Nearest to or: influenza, rafik, conscripts, rajah, tabbed, pictures, arborway, brienne,
# Nearest to which: vue, cnc, turboexpress, misrepresentation, astronaut, trajectory, windshield, fft,
# Nearest to assembly: snapping, smoothing, trapani, exorcist, farinelli, stevenson, folksong, contrabassoon,
# Nearest to woman: encampments, forked, usb, talas, sint, rugrats, tuna, wac,
# Nearest to cost: gorky, location, roared, rally, microwaves, ergonomic, turtledove, aldo,
# Nearest to resources: gif, monash, departs, liegnitz, greases, bergomi, yelled, liza,
# Nearest to numerous: rove, neuch, rushen, divisor, murat, rigours, biography, frenchy,
# Nearest to pope: ishtar, persecutors, miming, brillig, symbolism, bearer, roxen, pounded,
# Nearest to brother: sentiments, tasmania, mounted, epona, studd, starfleet, automation, compton,
# Nearest to units: subtracting, hate, polg, lorraine, xl, rains, harriet, amathus,
# Epoch 10/10 Iteration: 41100 Avg. Training loss: 2.9571 0.3372 sec/batch
# Epoch 10/10 Iteration: 41200 Avg. Training loss: 2.9446 0.3285 sec/batch
# Epoch 10/10 Iteration: 41300 Avg. Training loss: 2.9703 0.3300 sec/batch
# Epoch 10/10 Iteration: 41400 Avg. Training loss: 2.9267 0.3325 sec/batch
# Epoch 10/10 Iteration: 41500 Avg. Training loss: 2.9735 0.3282 sec/batch
# Epoch 10/10 Iteration: 41600 Avg. Training loss: 3.0047 0.3347 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.0351 0.3338 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.1154 0.3312 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.0208 0.3303 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 2.9630 0.3310 sec/batch
# Nearest to into: gerrymandering, kushan, masamune, margarine, warlock, sect, saskatchewan, literalism,
# Nearest to see: goalkeepers, overthrow, schola, monarch, fg, macmanus, blindness, astrologically,
# Nearest to new: issues, barrios, arrivals, guiana, reissue, dislodge, swell, calder,
# Nearest to at: following, claes, hobbyists, garagiola, attendances, crts, lond, pyne,
# Nearest to so: mistake, cyprian, chattanooga, connacht, hour, assembles, kimball, noodle,
# Nearest to many: weighed, bursa, seaborg, photographer, swords, verdun, lifting, weigh,
# Nearest to or: influenza, rafik, rajah, conscripts, pictures, brienne, tabbed, arborway,
# Nearest to which: vue, cnc, misrepresentation, turboexpress, trajectory, windshield, fft, astronaut,
# Nearest to assembly: snapping, exorcist, smoothing, trapani, farinelli, stevenson, folksong, contrabassoon,
# Nearest to woman: encampments, forked, usb, sint, talas, tuna, rugrats, rosso,
# Nearest to cost: gorky, location, roared, microwaves, ergonomic, rally, turtledove, aldo,
# Nearest to resources: gif, monash, departs, liza, liegnitz, yelled, greases, babylonia,
# Nearest to numerous: rove, rushen, neuch, divisor, murat, rammstein, rigours, biography,
# Nearest to pope: ishtar, persecutors, miming, bearer, brillig, skipped, symbolism, sumter,
# Nearest to brother: sentiments, tasmania, epona, studd, starfleet, mounted, automation, longbowmen,
# Nearest to units: subtracting, hate, polg, lorraine, xl, rains, harriet, amathus,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 2.9295 0.3355 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.0143 0.3276 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 2.8303 0.3296 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.0460 0.3309 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 2.9788 0.3311 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.0034 0.3322 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
